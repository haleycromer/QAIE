# %% [markdown]
# # 02 Preprocessing Notebook
# Convert multi-modal signals into high-dimensional tensors using STFT and entropy.

# %%
from dataset.multimodal_synthetic import generate_multimodal_event
from preprocessing.tensor_fusion import multimodal_tensor
import matplotlib.pyplot as plt

audio, vib, env = generate_multimodal_event()
tensor = multimodal_tensor(audio, vib, env)

plt.imshow(tensor[:,:,0].T, aspect='auto', cmap='viridis')
plt.title('Tensor - Amplitude Channel')
plt.xlabel('Time Frames')
plt.ylabel('Frequency Bins')
plt.show()
