# %% [markdown]
# # 08 Emotion Analysis Notebook
# Predict speaker emotion and demographics from synthetic voice.

# %%
from dataset.multimodal_synthetic import generate_multimodal_event
from preprocessing.tensor_fusion import multimodal_tensor
import numpy as np

# Simulate 3 emotional states
emotions = ['Happy', 'Sad', 'Angry']
for e in emotions:
    audio, vib, env = generate_multimodal_event()
    audio *= np.random.uniform(0.8,1.2)
    tensor = multimodal_tensor(audio, vib, env)
    print(f'Emotion: {e} | Tensor shape: {tensor.shape}')
