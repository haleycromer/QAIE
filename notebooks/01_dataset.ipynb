# %% [markdown]
# # 01 Dataset Notebook
# Generate and visualize multi-modal synthetic audio, vibration, and environmental signals.

# %%
import matplotlib.pyplot as plt
from dataset.multimodal_synthetic import generate_multimodal_event

# Generate synthetic multi-modal event
audio, vib, env = generate_multimodal_event()

# Plot signals
plt.figure(figsize=(12,4))
plt.plot(audio, label='Audio')
plt.plot(vib, label='Vibration')
plt.plot(env, label='Environmental')
plt.title('Synthetic Multi-Modal Event')
plt.legend()
plt.show()
